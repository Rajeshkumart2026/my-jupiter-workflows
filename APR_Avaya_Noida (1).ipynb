# %%
import subprocess

shortcut_path = r"C:\Users\rajeshkumar.t\Desktop\Modified New-APR Report - MM - Designed by APS.acsup"

try:
    subprocess.Popen([shortcut_path], shell=True)
    print("Shortcut opened successfully.")
except Exception as e:
    print("Error:", e)
# Out:
# Shortcut opened successfully.
