# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="openpyxl")
from sklearn.preprocessing import LabelEncoder

# %%
file_path = r"C:\Users\rajeshkumar.t\Desktop\ML\tranctions.csv"
df=pd.read_csv(file_path, low_memory=False)

# %%
print(df.head(5))
# Out:
#    transaction_yr  transaction_mth  transaction_wk transaction_dt  \
# 0            2025               12              49     2025-12-01
# 1            2025               12              49     2025-12-01
# 2            2025               12              49     2025-12-01
# 3            2025               12              49     2025-12-01
# 4            2025               12              49     2025-12-01
#
#   transaction_status transaction_source live_response_code payment_instrument  \
# 0             FAILED             iOSApp                NaN             CREDIT
# 1             FAILED         AndroidApp                NaN             FK_UPI
# 2             FAILED         MobileSite                NaN        UPI_COLLECT
# 3          INITIATED         AndroidApp                NaN             CREDIT
# 4             FAILED         MobileSite                NaN              DEBIT
#
#    bank_code hyp_flag  ... pg_id flipkart_emi_flag marketplace_context  \
# 0       AXIS   Others  ...   NaN                No            FLIPKART
# 1   FLIPKART   Others  ...   NaN                No                 NaN
# 2       GPAY   Others  ...   NaN                No            FLIPKART
# 3        RBL   Others  ...   NaN                No            FLIPKART
# 4  VISASBANK   Others  ...   NaN                No            FLIPKART
#
#   is_shopsy_order emi_flag adonc_flag count_of_tx acct_cnt tot_amt  \
# 0             NaN      NaN   No adonc           5        1    5230
# 1             NaN      NaN   No adonc           8        5   58650
# 2           False      NaN   No adonc           1        1      25
# 3           False      NaN   No adonc           1        1    1090
# 4             NaN      NaN   No adonc           3        1   21700
#
#   tot_eff_amt_paymnt
# 0               5230
# 1              58650
# 2                 25
# 3               1090
# 4              21700
#
# [5 rows x 24 columns]

# %%
label_encoders = {}
for col in df.select_dtypes(include=['object']).columns:
    le= LabelEncoder()
    df[col]=le.fit_transform(df[col])
    label_encoders[col]=le
    
corr_matrix= df.corr()
print("Correction Matris:")
print(corr_matrix)
# Out:
# Correction Matris:
#                      transaction_yr  transaction_mth  transaction_wk  \
# transaction_yr             1.000000        -1.000000       -0.998330
# transaction_mth           -1.000000         1.000000        0.998330
# transaction_wk            -0.998330         0.998330        1.000000
# transaction_dt             0.715536        -0.715536       -0.675105
# transaction_status        -0.000739         0.000739        0.001003
# transaction_source        -0.003585         0.003585        0.002930
# live_response_code         0.000858        -0.000858       -0.000694
# payment_instrument         0.002802        -0.002802       -0.002812
# bank_code                 -0.000536         0.000536       -0.000059
# hyp_flag                   0.007966        -0.007966       -0.007715
# asp_flag                   0.001297        -0.001297       -0.001061
# merchant_id               -0.002581         0.002581        0.002626
# merchant_status           -0.002368         0.002368        0.001885
# marketplace_id            -0.006222         0.006222        0.006046
# pg_id                     -0.018602         0.018602        0.018881
# flipkart_emi_flag          0.002415        -0.002415       -0.002156
# marketplace_context        0.006801        -0.006801       -0.006238
# is_shopsy_order           -0.003004         0.003004        0.002790
# emi_flag                   0.009742        -0.009742       -0.009446
# adonc_flag                -0.005381         0.005381        0.005267
# count_of_tx               -0.000487         0.000487        0.000449
# acct_cnt                  -0.000357         0.000357        0.000318
# tot_amt                   -0.001963         0.001963        0.001729
# tot_eff_amt_paymnt        -0.001904         0.001904        0.001675
#
#                      transaction_dt  transaction_status  transaction_source  \
# transaction_yr             0.715536           -0.000739           -0.003585
# transaction_mth           -0.715536            0.000739            0.003585
# transaction_wk            -0.675105            0.001003            0.002930
# transaction_dt             1.000000            0.002686           -0.010453
# transaction_status         0.002686            1.000000            0.079733
# transaction_source        -0.010453            0.079733            1.000000
# live_response_code         0.002294            0.394199            0.021086
# payment_instrument         0.002236           -0.091188            0.015716
# bank_code                 -0.008045            0.031139           -0.011391
# hyp_flag                   0.008780            0.044602           -0.009808
# asp_flag                   0.003723            0.006907           -0.006925
# merchant_id               -0.001155            0.054194            0.107333
# merchant_status           -0.007705           -0.916139           -0.083770
# marketplace_id            -0.006104           -0.362185            0.025664
# pg_id                     -0.008889           -0.016168            0.006753
# flipkart_emi_flag          0.004876            0.026796            0.004939
# marketplace_context        0.011826            0.086285            0.068134
# is_shopsy_order           -0.004205           -0.395850            0.000427
# emi_flag                   0.010188           -0.001566           -0.005241
# adonc_flag                -0.004957           -0.150576            0.012739
# count_of_tx               -0.000855            0.025016            0.000507
# acct_cnt                  -0.000777            0.023460           -0.009109
# tot_amt                   -0.004267            0.027210           -0.001194
# tot_eff_amt_paymnt        -0.004182            0.026952           -0.001031
#
#                      live_response_code  payment_instrument  bank_code  \
# transaction_yr                 0.000858            0.002802  -0.000536
# transaction_mth               -0.000858           -0.002802   0.000536
# transaction_wk                -0.000694           -0.002812  -0.000059
# transaction_dt                 0.002294            0.002236  -0.008045
# transaction_status             0.394199           -0.091188   0.031139
# transaction_source             0.021086            0.015716  -0.011391
# live_response_code             1.000000           -0.001056   0.035104
# payment_instrument            -0.001056            1.000000  -0.138870
# bank_code                      0.035104           -0.138870   1.000000
# hyp_flag                       0.052033           -0.064939   0.027015
# asp_flag                      -0.004345            0.023416   0.019565
# merchant_id                    0.022276            0.020658  -0.027472
# merchant_status               -0.360284            0.098441  -0.016683
# marketplace_id                -0.187039            0.001287  -0.001310
# pg_id                          0.063385            0.146508  -0.052312
# flipkart_emi_flag              0.037824            0.018436   0.002794
# marketplace_context            0.057042            0.134531  -0.023859
# is_shopsy_order               -0.201096            0.009308   0.000099
# emi_flag                      -0.008642           -0.110379   0.042477
# adonc_flag                    -0.057577           -0.068270   0.006401
# count_of_tx                    0.011712           -0.004525   0.019453
# acct_cnt                       0.011042           -0.003021   0.021917
# tot_amt                        0.018751           -0.000333   0.016472
# tot_eff_amt_paymnt             0.018560           -0.000277   0.016497
#
#                      hyp_flag  ...     pg_id  flipkart_emi_flag  \
# transaction_yr       0.007966  ... -0.018602           0.002415
# transaction_mth     -0.007966  ...  0.018602          -0.002415
# transaction_wk      -0.007715  ...  0.018881          -0.002156
# transaction_dt       0.008780  ... -0.008889           0.004876
# transaction_status   0.044602  ... -0.016168           0.026796
# transaction_source  -0.009808  ...  0.006753           0.004939
# live_response_code   0.052033  ...  0.063385           0.037824
# payment_instrument  -0.064939  ...  0.146508           0.018436
# bank_code            0.027015  ... -0.052312           0.002794
# hyp_flag             1.000000  ...  0.013650           0.016054
# asp_flag            -0.073041  ... -0.014111          -0.026642
# merchant_id          0.061895  ...  0.049289          -0.010446
# merchant_status     -0.051276  ... -0.007083          -0.019811
# marketplace_id      -0.137477  ...  0.075227           0.000351
# pg_id                0.013650  ...  1.000000          -0.098448
# flipkart_emi_flag    0.016054  ... -0.098448           1.000000
# marketplace_context -0.217395  ...  0.123920          -0.029622
# is_shopsy_order      0.001068  ...  0.061599           0.005342
# emi_flag            -0.096121  ... -0.013231          -0.161232
# adonc_flag           0.019109  ...  0.018461          -0.126353
# count_of_tx          0.003369  ... -0.014366          -0.000366
# acct_cnt             0.002421  ... -0.020453          -0.000388
# tot_amt              0.008880  ... -0.013133           0.015869
# tot_eff_amt_paymnt   0.008724  ... -0.013142           0.015496
#
#                      marketplace_context  is_shopsy_order  emi_flag  \
# transaction_yr                  0.006801        -0.003004  0.009742
# transaction_mth                -0.006801         0.003004 -0.009742
# transaction_wk                 -0.006238         0.002790 -0.009446
# transaction_dt                  0.011826        -0.004205  0.010188
# transaction_status              0.086285        -0.395850 -0.001566
# transaction_source              0.068134         0.000427 -0.005241
# live_response_code              0.057042        -0.201096 -0.008642
# payment_instrument              0.134531         0.009308 -0.110379
# bank_code                      -0.023859         0.000099  0.042477
# hyp_flag                       -0.217395         0.001068 -0.096121
# asp_flag                        0.119104        -0.080511  0.174474
# merchant_id                     0.547223         0.194857 -0.010691
# merchant_status                -0.150828         0.417553  0.011300
# marketplace_id                  0.080204         0.913006 -0.041009
# pg_id                           0.123920         0.061599 -0.013231
# flipkart_emi_flag              -0.029622         0.005342 -0.161232
# marketplace_context             1.000000         0.032624  0.084949
# is_shopsy_order                 0.032624         1.000000 -0.041586
# emi_flag                        0.084949        -0.041586  1.000000
# adonc_flag                      0.015044         0.053356  0.022588
# count_of_tx                    -0.009985        -0.008287  0.005461
# acct_cnt                       -0.006677        -0.012848  0.005005
# tot_amt                        -0.017445        -0.002867 -0.007660
# tot_eff_amt_paymnt             -0.017192        -0.002885 -0.007058
#
#                      adonc_flag  count_of_tx  acct_cnt   tot_amt  \
# transaction_yr        -0.005381    -0.000487 -0.000357 -0.001963
# transaction_mth        0.005381     0.000487  0.000357  0.001963
# transaction_wk         0.005267     0.000449  0.000318  0.001729
# transaction_dt        -0.004957    -0.000855 -0.000777 -0.004267
# transaction_status    -0.150576     0.025016  0.023460  0.027210
# transaction_source     0.012739     0.000507 -0.009109 -0.001194
# live_response_code    -0.057577     0.011712  0.011042  0.018751
# payment_instrument    -0.068270    -0.004525 -0.003021 -0.000333
# bank_code              0.006401     0.019453  0.021917  0.016472
# hyp_flag               0.019109     0.003369  0.002421  0.008880
# asp_flag              -0.034249     0.016889  0.015589 -0.011387
# merchant_id            0.018036    -0.011802 -0.003364 -0.013778
# merchant_status        0.038644    -0.026216 -0.024239 -0.028788
# marketplace_id         0.055312    -0.010074 -0.014453 -0.006219
# pg_id                  0.018461    -0.014366 -0.020453 -0.013133
# flipkart_emi_flag     -0.126353    -0.000366 -0.000388  0.015869
# marketplace_context    0.015044    -0.009985 -0.006677 -0.017445
# is_shopsy_order        0.053356    -0.008287 -0.012848 -0.002867
# emi_flag               0.022588     0.005461  0.005005 -0.007660
# adonc_flag             1.000000     0.001715  0.001568  0.002615
# count_of_tx            0.001715     1.000000  0.953392  0.486418
# acct_cnt               0.001568     0.953392  1.000000  0.459702
# tot_amt                0.002615     0.486418  0.459702  1.000000
# tot_eff_amt_paymnt     0.002567     0.486946  0.460196  0.999955
#
#                      tot_eff_amt_paymnt
# transaction_yr                -0.001904
# transaction_mth                0.001904
# transaction_wk                 0.001675
# transaction_dt                -0.004182
# transaction_status             0.026952
# transaction_source            -0.001031
# live_response_code             0.018560
# payment_instrument            -0.000277
# bank_code                      0.016497
# hyp_flag                       0.008724
# asp_flag                      -0.010941
# merchant_id                   -0.013752
# merchant_status               -0.028509
# marketplace_id                -0.006144
# pg_id                         -0.013142
# flipkart_emi_flag              0.015496
# marketplace_context           -0.017192
# is_shopsy_order               -0.002885
# emi_flag                      -0.007058
# adonc_flag                     0.002567
# count_of_tx                    0.486946
# acct_cnt                       0.460196
# tot_amt                        0.999955
# tot_eff_amt_paymnt             1.000000
#
# [24 rows x 24 columns]
